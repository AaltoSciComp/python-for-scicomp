# %%
import altair as alt
import pandas as pd
import numpy as np

rand = np.random.RandomState(42)

df = pd.DataFrame({
    'xval': range(100),
    'yval': rand.randn(100).cumsum()
})

slider = alt.binding_range(min=0, max=100, step=1)
cutoff = alt.param(bind=slider, value=50)

alt.Chart(df).mark_point().encode(
    x='xval',
    y='yval',
    color=alt.condition(
        alt.datum.xval < cutoff,
        alt.value('red'), alt.value('blue')
    )
).add_params(
    cutoff
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
import pandas as pd
import numpy as np

rand = np.random.RandomState(42)

df = pd.DataFrame({
    'xval': range(100),
    'yval': rand.randn(100).cumsum()
})

slider = alt.binding_range(min=0, max=100, step=1)
cutoff = alt.param(bind=slider, value=50)

print(df)

alt.Chart(df).mark_point().encode(
    x='xval',
    y='yval',
    color=alt.condition(
        alt.datum.xval < cutoff,
        alt.value('red'), alt.value('blue')
    )
).add_params(
    cutoff
)
# Out:
#     xval       yval
# 0      0   0.496714
# 1      1   0.358450
# 2      2   1.006138
# 3      3   2.529168
# 4      4   2.295015
# ..   ...        ...
# 95    95 -10.712354
# 96    96 -10.416233
# 97    97 -10.155178
# 98    98 -10.150065
# 99    99 -10.384652
#
# [100 rows x 2 columns]
# alt.Chart(...)

# %%
import pandas as pd

df.to_csv("data.csv", index=False)

# %%
# on your computer
# mydata = pd.read_csv("mydata.csv")

# fetching data from the lesson
url_prefix = "https://raw.githubusercontent.com/AaltoSciComp/python-for-scicomp/master/resources/data/plotting/"
mydata = pd.read_csv(url_prefix + "exercise-2.csv")

mydata
# Out:
#    xval  yval
# 0     1   7.7
# 1     2   6.6
# 2     3   4.5
# 3     4   9.8
# 4     5  17.7
# 5     6  25.4
# 6     7  26.7
# 7     8  25.1
# 8     9  19.3
# 9    10   9.8

# %%
import altair as alt
import pandas as pd
# import numpy as np

# rand = np.random.RandomState(42)

# df = pd.DataFrame({
#     'xval': range(100),
#     'yval': rand.randn(100).cumsum()
# })

slider = alt.binding_range(min=0, max=100, step=1)
cutoff = alt.param(bind=slider, value=50)

# print(df)
df = pd.read_csv("mydata.csv")

alt.Chart(df).mark_point().encode(
    x='xval',
    y='yval',
    color=alt.condition(
        alt.datum.xval < cutoff,
        alt.value('red'), alt.value('blue')
    )
).add_params(
    cutoff
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
import pandas as pd

slider = alt.binding_range(min=0, max=30, step=1)
cutoff = alt.param(bind=slider, value=15)

df = pd.read_csv("mydata.csv")

alt.Chart(df).mark_point().encode(
    x='xval',
    y='yval',
    color=alt.condition(
        alt.datum.yval < cutoff,
        alt.value('red'), alt.value('blue')
    )
).add_params(
    cutoff
)
# Out:
# alt.Chart(...)
